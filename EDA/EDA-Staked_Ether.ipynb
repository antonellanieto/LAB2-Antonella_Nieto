# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Revisión de Lido Staked Ether desde 2020 hasta fin 2022**

# %% [markdown]
# **Creación del DataFrame.**

# %%
df = pd.read_csv('staked_date.csv')
df
# Out:
#       Timestamp        Price        Date
# 0    2020-12-22   617.164997  2020-12-22
# 1    2020-12-23   617.164997  2020-12-23
# 2    2020-12-24   596.767711  2020-12-24
# 3    2020-12-25   611.504712  2020-12-25
# 4    2020-12-26   624.800420  2020-12-26
# ..          ...          ...         ...
# 736  2022-12-28  1198.878290  2022-12-28
# 737  2022-12-29  1177.138099  2022-12-29
# 738  2022-12-30  1188.107850  2022-12-30
# 739  2022-12-31  1184.730451  2022-12-31
# 740  2023-01-01  1180.264013  2023-01-01
#
# [741 rows x 3 columns]

# %% [markdown]
# **Elimino columna que no será útil para el análisis.**

# %%
df = df.drop('Date', axis=1)
df
# Out:
#       Timestamp        Price
# 0    2020-12-22   617.164997
# 1    2020-12-23   617.164997
# 2    2020-12-24   596.767711
# 3    2020-12-25   611.504712
# 4    2020-12-26   624.800420
# ..          ...          ...
# 736  2022-12-28  1198.878290
# 737  2022-12-29  1177.138099
# 738  2022-12-30  1188.107850
# 739  2022-12-31  1184.730451
# 740  2023-01-01  1180.264013
#
# [741 rows x 2 columns]

# %% [markdown]
# **Verifico si existen valores duplicados.**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Renombro la columna Timesstamp a Date.**

# %%
df.rename(columns={'Timestamp': 'Date'}, inplace=True)
df
# Out:
#            Date        Price
# 0    2020-12-22   617.164997
# 1    2020-12-23   617.164997
# 2    2020-12-24   596.767711
# 3    2020-12-25   611.504712
# 4    2020-12-26   624.800420
# ..          ...          ...
# 736  2022-12-28  1198.878290
# 737  2022-12-29  1177.138099
# 738  2022-12-30  1188.107850
# 739  2022-12-31  1184.730451
# 740  2023-01-01  1180.264013
#
# [741 rows x 2 columns]

# %% [markdown]
# **Verifico si hay campos nulos.**

# %%
df.isna().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %% [markdown]
# **Precio más alto alcanzado.**

# %%
highest = df.loc[df['Price'].idxmax()]
highest
# Out:
# Date      2021-11-09
# Price    4775.452755
# Name: 322, dtype: object

# %% [markdown]
# **Precio más bajo alcanzado.**

# %%
lowest = df.loc[df['Price'].idxmin()]
lowest
# Out:
# Date     2020-12-24
# Price    596.767711
# Name: 2, dtype: object

# %% [markdown]
# **Elimino la última fila, ya que corresponde a una fecha que no voy a incluir en el análisis.**

# %%
df=df.drop(df.index[-1])
df
# Out:
#            Date        Price
# 0    2020-12-22   617.164997
# 1    2020-12-23   617.164997
# 2    2020-12-24   596.767711
# 3    2020-12-25   611.504712
# 4    2020-12-26   624.800420
# ..          ...          ...
# 735  2022-12-27  1214.448830
# 736  2022-12-28  1198.878290
# 737  2022-12-29  1177.138099
# 738  2022-12-30  1188.107850
# 739  2022-12-31  1184.730451
#
# [740 rows x 2 columns]

# %% [markdown]
# # **Visualización por año**

# %% [markdown]
# # **2020**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2020 = df[df['Date'].dt.year == 2020]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2020, x='Date', y='Price')
plt.title('Flujo de precios durante 2020')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2021**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2021 = df[df['Date'].dt.year == 2021]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2021, x='Date', y='Price')
plt.title('Flujo de precios durante 2021')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2022**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2022 = df[df['Date'].dt.year == 2022]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2022, x='Date', y='Price')
plt.title('Flujo de precios durante 2022')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()
