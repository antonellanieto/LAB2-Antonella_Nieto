# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Revisión de Bitcoin desde enero 2015 hasta fin 2022**

# %% [markdown]
# **Creación de DataFrame.**

# %%
df = pd.read_csv('bitcoin_date_price.csv')
df
# Out:
#                           Timestamp         Price  \
# 0     2015-01-02 00:00:00.000000000    314.446000
# 1     2015-01-03 00:00:00.000000000    286.572000
# 2     2015-01-04 00:00:00.000000000    260.936000
# 3     2015-01-05 00:00:00.000000000    273.220000
# 4     2015-01-06 00:00:00.000000000    285.373800
# ...                             ...           ...
# 2916  2022-12-28 00:00:00.000000000  16701.840211
# 2917  2022-12-29 00:00:00.000000000  16538.906094
# 2918  2022-12-30 00:00:00.000000000  16644.379087
# 2919  2022-12-31 00:00:00.000000000  16604.020520
# 2920  2023-01-01 00:00:00.000000000  16540.693625
#
#                                Date
# 0     2015-01-02 00:00:00.000000000
# 1     2015-01-03 00:00:00.000000000
# 2     2015-01-04 00:00:00.000000000
# 3     2015-01-05 00:00:00.000000000
# 4     2015-01-06 00:00:00.000000000
# ...                             ...
# 2916  2022-12-28 00:00:00.000000000
# 2917  2022-12-29 00:00:00.000000000
# ...

# %% [markdown]
# **Elimino columna que no es útil.**

# %%
df = df.drop('Date', axis=1)
df
# Out:
#                           Timestamp         Price
# 0     2015-01-02 00:00:00.000000000    314.446000
# 1     2015-01-03 00:00:00.000000000    286.572000
# 2     2015-01-04 00:00:00.000000000    260.936000
# 3     2015-01-05 00:00:00.000000000    273.220000
# 4     2015-01-06 00:00:00.000000000    285.373800
# ...                             ...           ...
# 2916  2022-12-28 00:00:00.000000000  16701.840211
# 2917  2022-12-29 00:00:00.000000000  16538.906094
# 2918  2022-12-30 00:00:00.000000000  16644.379087
# 2919  2022-12-31 00:00:00.000000000  16604.020520
# 2920  2023-01-01 00:00:00.000000000  16540.693625
#
# [2921 rows x 2 columns]

# %% [markdown]
# **Verifico si tiene duplicados.**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Renombro TimeStamp a Date, ya que previamente transformé la fecha de Timesstamp a formato Date.**

# %%
df.rename(columns={'Timestamp': 'Date'}, inplace=True)
df
# Out:
#                                Date         Price
# 0     2015-01-02 00:00:00.000000000    314.446000
# 1     2015-01-03 00:00:00.000000000    286.572000
# 2     2015-01-04 00:00:00.000000000    260.936000
# 3     2015-01-05 00:00:00.000000000    273.220000
# 4     2015-01-06 00:00:00.000000000    285.373800
# ...                             ...           ...
# 2916  2022-12-28 00:00:00.000000000  16701.840211
# 2917  2022-12-29 00:00:00.000000000  16538.906094
# 2918  2022-12-30 00:00:00.000000000  16644.379087
# 2919  2022-12-31 00:00:00.000000000  16604.020520
# 2920  2023-01-01 00:00:00.000000000  16540.693625
#
# [2921 rows x 2 columns]

# %% [markdown]
# **Verifico si hay campos nulos.**

# %%
df.isna().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %% [markdown]
# **Precio más alto alcanzado.**

# %%
highest = df.loc[df['Price'].idxmax()]
highest
# Out:
# Date     2021-11-09 00:00:00.000000000
# Price                     67617.015545
# Name: 2502, dtype: object

# %% [markdown]
# **Precio más bajo alcanzado.**

# %%
lowest = df.loc[df['Price'].idxmin()]
lowest
# Out:
# Date     2015-01-14 00:00:00.000000000
# Price                         172.1479
# Name: 12, dtype: object

# %% [markdown]
# **Elimino la última fila, ya que corresponde a una fecha que no voy a incluir en el análisis.**

# %%
df=df.drop(df.index[-1])
df
# Out:
#                                Date         Price
# 0     2015-01-02 00:00:00.000000000    314.446000
# 1     2015-01-03 00:00:00.000000000    286.572000
# 2     2015-01-04 00:00:00.000000000    260.936000
# 3     2015-01-05 00:00:00.000000000    273.220000
# 4     2015-01-06 00:00:00.000000000    285.373800
# ...                             ...           ...
# 2915  2022-12-27 00:00:00.000000000  16900.081872
# 2916  2022-12-28 00:00:00.000000000  16701.840211
# 2917  2022-12-29 00:00:00.000000000  16538.906094
# 2918  2022-12-30 00:00:00.000000000  16644.379087
# 2919  2022-12-31 00:00:00.000000000  16604.020520
#
# [2920 rows x 2 columns]

# %% [markdown]
# # **Visualización por año**

# %% [markdown]
# # **2015**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2015 = df[df['Date'].dt.year == 2015]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2015, x='Date', y='Price')
plt.title('Flujo de precios durante 2015')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2016**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2016 = df[df['Date'].dt.year == 2016]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2016, x='Date', y='Price')
plt.title('Flujo de precios durante 2016')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2017**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2017 = df[df['Date'].dt.year == 2017]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2017, x='Date', y='Price')
plt.title('Flujo de precios durante 2017')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2018**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2018 = df[df['Date'].dt.year == 2018]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2018, x='Date', y='Price')
plt.title('Flujo de precios durante 2018')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2019**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2019 = df[df['Date'].dt.year == 2019]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2019, x='Date', y='Price')
plt.title('Flujo de precios durante 2019')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2020**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2020 = df[df['Date'].dt.year == 2020]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2020, x='Date', y='Price')
plt.title('Flujo de precios durante 2020')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2021**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2021 = df[df['Date'].dt.year == 2021]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2021, x='Date', y='Price')
plt.title('Flujo de precios durante 2021')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2022**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2022 = df[df['Date'].dt.year == 2022]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2022, x='Date', y='Price')
plt.title('Flujo de precios durante 2022')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()
