# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Revisión de USD Coind desde 2018 hasta fin 2022**

# %% [markdown]
# **Creación de DataFrame.**

# %%
df = pd.read_csv('usd-coin_data.csv')
df
# Out:
#        Timestamp     Price        Date
# 0     2018-10-05  1.006242  2018-10-05
# 1     2018-10-06  1.001530  2018-10-06
# 2     2018-10-07  1.001177  2018-10-07
# 3     2018-10-08  1.001906  2018-10-08
# 4     2018-10-09  1.001983  2018-10-09
# ...          ...       ...         ...
# 1545  2022-12-28  0.999816  2022-12-28
# 1546  2022-12-29  1.000596  2022-12-29
# 1547  2022-12-30  1.000360  2022-12-30
# 1548  2022-12-31  1.000409  2022-12-31
# 1549  2023-01-01  1.000615  2023-01-01
#
# [1550 rows x 3 columns]

# %% [markdown]
# **Elimino columna que no es útil.**

# %%
df = df.drop('Date', axis=1)
df
# Out:
#        Timestamp     Price
# 0     2018-10-05  1.006242
# 1     2018-10-06  1.001530
# 2     2018-10-07  1.001177
# 3     2018-10-08  1.001906
# 4     2018-10-09  1.001983
# ...          ...       ...
# 1545  2022-12-28  0.999816
# 1546  2022-12-29  1.000596
# 1547  2022-12-30  1.000360
# 1548  2022-12-31  1.000409
# 1549  2023-01-01  1.000615
#
# [1550 rows x 2 columns]

# %% [markdown]
# **Verifico si tiene duplicados.**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Renombro TimeStamp a Date, ya que previamente transformé la fecha de Timesstamp a formato Date.**

# %%
df.rename(columns={'Timestamp': 'Date'}, inplace=True)
df
# Out:
#             Date     Price
# 0     2018-10-05  1.006242
# 1     2018-10-06  1.001530
# 2     2018-10-07  1.001177
# 3     2018-10-08  1.001906
# 4     2018-10-09  1.001983
# ...          ...       ...
# 1545  2022-12-28  0.999816
# 1546  2022-12-29  1.000596
# 1547  2022-12-30  1.000360
# 1548  2022-12-31  1.000409
# 1549  2023-01-01  1.000615
#
# [1550 rows x 2 columns]

# %% [markdown]
# **Verifico si hay campos nulos.**

# %%
df.isna().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %% [markdown]
# **Precio más alto alcanzado.**

# %%
highest = df.loc[df['Price'].idxmax()]
highest
# Out:
# Date     2018-11-15
# Price      1.043465
# Name: 41, dtype: object

# %% [markdown]
# **Precio más bajo alcanzado.**

# %%
lowest = df.loc[df['Price'].idxmin()]
lowest
# Out:
# Date     2018-12-30
# Price      0.971688
# Name: 86, dtype: object

# %% [markdown]
# **Elimino la última fila, ya que corresponde a una fecha que no voy a incluir en el análisis.**

# %%
df=df.drop(df.index[-1])
df
# Out:
#             Date     Price
# 0     2018-10-05  1.006242
# 1     2018-10-06  1.001530
# 2     2018-10-07  1.001177
# 3     2018-10-08  1.001906
# 4     2018-10-09  1.001983
# ...          ...       ...
# 1544  2022-12-27  1.000886
# 1545  2022-12-28  0.999816
# 1546  2022-12-29  1.000596
# 1547  2022-12-30  1.000360
# 1548  2022-12-31  1.000409
#
# [1549 rows x 2 columns]

# %% [markdown]
# # **Visualización por año**

# %% [markdown]
# # **2018**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2018 = df[df['Date'].dt.year == 2018]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2018, x='Date', y='Price')
plt.title('Flujo de precios durante 2018')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2019**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2019 = df[df['Date'].dt.year == 2019]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2019, x='Date', y='Price')
plt.title('Flujo de precios durante 2019')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2020**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2020 = df[df['Date'].dt.year == 2020]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2020, x='Date', y='Price')
plt.title('Flujo de precios durante 2020')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2021**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2021 = df[df['Date'].dt.year == 2021]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2021, x='Date', y='Price')
plt.title('Flujo de precios durante 2021')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2022**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2022 = df[df['Date'].dt.year == 2022]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2022, x='Date', y='Price')
plt.title('Flujo de precios durante 2022')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()
