# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Revisión de BNB desde 2017 hasta fin 2022**

# %% [markdown]
# **Creación de DataFrame.**

# %%
df = pd.read_csv('BNB_date.csv')
df
# Out:
#                           Timestamp       Price                           Date
# 0     2017-09-16 00:00:00.000000000    0.107251  2017-09-16 00:00:00.000000000
# 1     2017-09-17 00:00:00.000000000    0.154041  2017-09-17 00:00:00.000000000
# 2     2017-09-18 00:00:00.000000000    0.173491  2017-09-18 00:00:00.000000000
# 3     2017-09-19 00:00:00.000000000    0.168334  2017-09-19 00:00:00.000000000
# 4     2017-09-20 00:00:00.000000000    0.166628  2017-09-20 00:00:00.000000000
# ...                             ...         ...                            ...
# 1927  2022-12-28 00:00:00.000000000  246.444618  2022-12-28 00:00:00.000000000
# 1928  2022-12-29 00:00:00.000000000  244.034460  2022-12-29 00:00:00.000000000
# 1929  2022-12-30 00:00:00.000000000  246.450758  2022-12-30 00:00:00.000000000
# 1930  2022-12-31 00:00:00.000000000  245.837811  2022-12-31 00:00:00.000000000
# 1931  2023-01-01 00:00:00.000000000  246.659361  2023-01-01 00:00:00.000000000
#
# [1932 rows x 3 columns]

# %% [markdown]
# **Elimino columna que no es útil.**

# %%
df = df.drop('Date', axis=1)
df
# Out:
#                           Timestamp       Price
# 0     2017-09-16 00:00:00.000000000    0.107251
# 1     2017-09-17 00:00:00.000000000    0.154041
# 2     2017-09-18 00:00:00.000000000    0.173491
# 3     2017-09-19 00:00:00.000000000    0.168334
# 4     2017-09-20 00:00:00.000000000    0.166628
# ...                             ...         ...
# 1927  2022-12-28 00:00:00.000000000  246.444618
# 1928  2022-12-29 00:00:00.000000000  244.034460
# 1929  2022-12-30 00:00:00.000000000  246.450758
# 1930  2022-12-31 00:00:00.000000000  245.837811
# 1931  2023-01-01 00:00:00.000000000  246.659361
#
# [1932 rows x 2 columns]

# %% [markdown]
# **Verifico si tiene duplicados.**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Renombro TimeStamp a Date, ya que previamente transformé la fecha de Timesstamp a formato Date.**

# %%
df.rename(columns={'Timestamp': 'Date'}, inplace=True)
df
# Out:
#                                Date       Price
# 0     2017-09-16 00:00:00.000000000    0.107251
# 1     2017-09-17 00:00:00.000000000    0.154041
# 2     2017-09-18 00:00:00.000000000    0.173491
# 3     2017-09-19 00:00:00.000000000    0.168334
# 4     2017-09-20 00:00:00.000000000    0.166628
# ...                             ...         ...
# 1927  2022-12-28 00:00:00.000000000  246.444618
# 1928  2022-12-29 00:00:00.000000000  244.034460
# 1929  2022-12-30 00:00:00.000000000  246.450758
# 1930  2022-12-31 00:00:00.000000000  245.837811
# 1931  2023-01-01 00:00:00.000000000  246.659361
#
# [1932 rows x 2 columns]

# %% [markdown]
# **Verifico si hay campos nulos.**

# %%
df.isna().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %% [markdown]
# **Precio más alto alcanzado.**

# %%
highest = df.loc[df['Price'].idxmax()]
highest
# Out:
# Date     2021-05-04 00:00:00.000000000
# Price                       675.098974
# Name: 1324, dtype: object

# %% [markdown]
# **Precio más bajo alcanzado.**

# %%
lowest = df.loc[df['Price'].idxmin()]
lowest
# Out:
# Date     2017-10-19 00:00:00.000000000
# Price                         0.039818
# Name: 32, dtype: object

# %% [markdown]
# **Elimino la última fila, ya que corresponde a una fecha que no voy a incluir en el análisis.**

# %%
df=df.drop(df.index[-1])
df
# Out:
#                                Date       Price
# 0     2017-09-16 00:00:00.000000000    0.107251
# 1     2017-09-17 00:00:00.000000000    0.154041
# 2     2017-09-18 00:00:00.000000000    0.173491
# 3     2017-09-19 00:00:00.000000000    0.168334
# 4     2017-09-20 00:00:00.000000000    0.166628
# ...                             ...         ...
# 1926  2022-12-27 00:00:00.000000000  243.750518
# 1927  2022-12-28 00:00:00.000000000  246.444618
# 1928  2022-12-29 00:00:00.000000000  244.034460
# 1929  2022-12-30 00:00:00.000000000  246.450758
# 1930  2022-12-31 00:00:00.000000000  245.837811
#
# [1931 rows x 2 columns]

# %% [markdown]
# # **Visualización por año**

# %% [markdown]
# # **2017**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2017 = df[df['Date'].dt.year == 2017]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2017, x='Date', y='Price')
plt.title('Flujo de precios durante 2017')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2018**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2018 = df[df['Date'].dt.year == 2018]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2018, x='Date', y='Price')
plt.title('Flujo de precios durante 2018')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2019**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2019 = df[df['Date'].dt.year == 2019]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2019, x='Date', y='Price')
plt.title('Flujo de precios durante 2019')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2020**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2020 = df[df['Date'].dt.year == 2020]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2020, x='Date', y='Price')
plt.title('Flujo de precios durante 2020')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2021**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2021 = df[df['Date'].dt.year == 2021]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2021, x='Date', y='Price')
plt.title('Flujo de precios durante 2021')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2022**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2022 = df[df['Date'].dt.year == 2022]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2022, x='Date', y='Price')
plt.title('Flujo de precios durante 2022')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()
