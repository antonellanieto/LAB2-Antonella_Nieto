# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Revisión de Solana desde 2020 hasta fin 2022**

# %% [markdown]
# **Creación de DataFrame.**

# %%
df = pd.read_csv('solana_date.csv')
df
# Out:
#       Timestamp      Price        Date
# 0    2020-04-11   0.957606  2020-04-11
# 1    2020-04-12   0.784711  2020-04-12
# 2    2020-04-13   0.875994  2020-04-13
# 3    2020-04-14   0.786712  2020-04-14
# 4    2020-04-15   0.666673  2020-04-15
# ..          ...        ...         ...
# 991  2022-12-28  11.080349  2022-12-28
# 992  2022-12-29   9.770825  2022-12-29
# 993  2022-12-30   9.597795  2022-12-30
# 994  2022-12-31   9.888231  2022-12-31
# 995  2023-01-01   9.961463  2023-01-01
#
# [996 rows x 3 columns]

# %% [markdown]
# **Elimino columna que no es útil.**

# %%
df = df.drop('Date', axis=1)
df
# Out:
#       Timestamp      Price
# 0    2020-04-11   0.957606
# 1    2020-04-12   0.784711
# 2    2020-04-13   0.875994
# 3    2020-04-14   0.786712
# 4    2020-04-15   0.666673
# ..          ...        ...
# 991  2022-12-28  11.080349
# 992  2022-12-29   9.770825
# 993  2022-12-30   9.597795
# 994  2022-12-31   9.888231
# 995  2023-01-01   9.961463
#
# [996 rows x 2 columns]

# %% [markdown]
# **Verifico si tiene duplicados.**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Renombro TimeStamp a Date, ya que previamente transformé la fecha de Timesstamp a formato Date.**

# %%
df.rename(columns={'Timestamp': 'Date'}, inplace=True)
df
# Out:
#            Date      Price
# 0    2020-04-11   0.957606
# 1    2020-04-12   0.784711
# 2    2020-04-13   0.875994
# 3    2020-04-14   0.786712
# 4    2020-04-15   0.666673
# ..          ...        ...
# 991  2022-12-28  11.080349
# 992  2022-12-29   9.770825
# 993  2022-12-30   9.597795
# 994  2022-12-31   9.888231
# 995  2023-01-01   9.961463
#
# [996 rows x 2 columns]

# %% [markdown]
# **Verifico si hay campos nulos.**

# %%
df.isna().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %% [markdown]
# **Precio más alto alcanzado.**

# %%
highest = df.loc[df['Price'].idxmax()]
highest
# Out:
# Date     2021-11-07
# Price    259.239558
# Name: 575, dtype: object

# %% [markdown]
# **Precio más bajo alcanzado.**

# %%
lowest = df.loc[df['Price'].idxmin()]
lowest
# Out:
# Date     2020-05-12
# Price      0.513923
# Name: 31, dtype: object

# %% [markdown]
# **Elimino la última fila, ya que corresponde a una fecha que no voy a incluir en el análisis.**

# %%
df=df.drop(df.index[-1])
df
# Out:
#            Date      Price
# 0    2020-04-11   0.957606
# 1    2020-04-12   0.784711
# 2    2020-04-13   0.875994
# 3    2020-04-14   0.786712
# 4    2020-04-15   0.666673
# ..          ...        ...
# 990  2022-12-27  11.301306
# 991  2022-12-28  11.080349
# 992  2022-12-29   9.770825
# 993  2022-12-30   9.597795
# 994  2022-12-31   9.888231
#
# [995 rows x 2 columns]

# %% [markdown]
# # **Visualización por año**

# %% [markdown]
# # **2020**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2020 = df[df['Date'].dt.year == 2020]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2020, x='Date', y='Price')
plt.title('Flujo de precios durante 2020')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2021**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2021 = df[df['Date'].dt.year == 2021]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2021, x='Date', y='Price')
plt.title('Flujo de precios durante 2021')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **2022**

# %%
X = df['Date']
y = df['Price']

df['Date'] = pd.to_datetime(df['Date'])
df_2022 = df[df['Date'].dt.year == 2022]

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_2022, x='Date', y='Price')
plt.title('Flujo de precios durante 2022')
plt.xlabel('Fecha')
plt.ylabel('Precio')
plt.xticks(rotation=45)
plt.show()
